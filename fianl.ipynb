# %% [markdown]
# # 503 Final Project
#
# ### Team name: GPT Chasers
# ### Team Member: Hongxuan An, Xingjian Liu, Yi Liu

# %%
import pandas as pd
import numpy as np
import pyreadstat
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /var/folders/25/11_3tsc15qdghq5pm9g0v2wm0000gn/T/ipykernel_35955/2569493232.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df, meta = pyreadstat.read_xport('/Users/an/Documents/Umich/stats 503/Final Project/DR1IFF_J.XPT')
df.head()
# Out:
#       SEQN        WTDRD1        WTDR2D  DR1ILINE  DR1DRSTZ  DR1EXMER  DRABF  \
# 0  93704.0  81714.005497  82442.869214       1.0       1.0      49.0    2.0
# 1  93704.0  81714.005497  82442.869214       2.0       1.0      49.0    2.0
# 2  93704.0  81714.005497  82442.869214       3.0       1.0      49.0    2.0
# 3  93704.0  81714.005497  82442.869214       4.0       1.0      49.0    2.0
# 4  93704.0  81714.005497  82442.869214       5.0       1.0      49.0    2.0
#
#    DRDINT  DR1DBIH  DR1DAY  ...  DR1IM181  DR1IM201  DR1IM221  DR1IP182  \
# 0     2.0      7.0     2.0  ...     4.549     0.040     0.000     3.669
# 1     2.0      7.0     2.0  ...     0.459     0.002     0.000     0.072
# 2     2.0      7.0     2.0  ...     4.656     0.106     0.009     5.485
# 3     2.0      7.0     2.0  ...     0.001     0.000     0.000     0.002
# 4     2.0      7.0     2.0  ...     2.043     0.041     0.000     1.418
#
#    DR1IP183  DR1IP184  DR1IP204  DR1IP205  DR1IP225  DR1IP226
# 0     0.467       0.0     0.022       0.0     0.001     0.006
# 1     0.007       0.0     0.002       0.0     0.000     0.000
# 2     0.226       0.0     0.040       0.0     0.003     0.002
# 3     0.000       0.0     0.000       0.0     0.000     0.000
# 4     0.263       0.0     0.000       0.0     0.000     0.000
#
# [5 rows x 84 columns]

# %%
df.columns
# Out:
# Index(['SEQN', 'WTDRD1', 'WTDR2D', 'DR1ILINE', 'DR1DRSTZ', 'DR1EXMER', 'DRABF',
#        'DRDINT', 'DR1DBIH', 'DR1DAY', 'DR1LANG', 'DR1CCMNM', 'DR1CCMTX',
#        'DR1_020', 'DR1_030Z', 'DR1FS', 'DR1_040Z', 'DR1IFDCD', 'DR1IGRMS',
#        'DR1IKCAL', 'DR1IPROT', 'DR1ICARB', 'DR1ISUGR', 'DR1IFIBE', 'DR1ITFAT',
#        'DR1ISFAT', 'DR1IMFAT', 'DR1IPFAT', 'DR1ICHOL', 'DR1IATOC', 'DR1IATOA',
#        'DR1IRET', 'DR1IVARA', 'DR1IACAR', 'DR1IBCAR', 'DR1ICRYP', 'DR1ILYCO',
#        'DR1ILZ', 'DR1IVB1', 'DR1IVB2', 'DR1INIAC', 'DR1IVB6', 'DR1IFOLA',
#        'DR1IFA', 'DR1IFF', 'DR1IFDFE', 'DR1ICHL', 'DR1IVB12', 'DR1IB12A',
#        'DR1IVC', 'DR1IVD', 'DR1IVK', 'DR1ICALC', 'DR1IPHOS', 'DR1IMAGN',
#        'DR1IIRON', 'DR1IZINC', 'DR1ICOPP', 'DR1ISODI', 'DR1IPOTA', 'DR1ISELE',
#        'DR1ICAFF', 'DR1ITHEO', 'DR1IALCO', 'DR1IMOIS', 'DR1IS040', 'DR1IS060',
#        'DR1IS080', 'DR1IS100', 'DR1IS120', 'DR1IS140', 'DR1IS160', 'DR1IS180',
#        'DR1IM161', 'DR1IM181', 'DR1IM201', 'DR1IM221', 'DR1IP182', 'DR1IP183',
#        'DR1IP184', 'DR1IP204', 'DR1IP205', 'DR1IP225', 'DR1IP226'],
#       dtype='object')

# %%
cols = ['DR1ISFAT', 'DR1IMFAT', 'DR1IPFAT', 'DR1IKCAL', 'DR1IPROT', 'DR1ICARB', 'DR1ISUGR', 'DR1IFIBE', 'DR1ITFAT', 'DR1CCMTX']
dietary = df[cols]
dietary.columns = ['Total saturated fatty acids', 'Total monounsaturated fatty acids', ' Total polyunsaturated fatty acids', 'Energy', 'Protein', 'Carbohydrate', 'Sugars', 'Dietary Fiber', 'Total Fat', 'food type']

# %%
dietary.head()
# Out:
#     Total saturated fatty acids  Total monounsaturated fatty acids  \
# 8                         0.172                              0.385
# 12                        3.317                              1.318
# 27                        0.000                              0.000
# 28                        4.409                              1.210
# 29                        1.055                              1.979
#
#      Total polyunsaturated fatty acids  Energy  Protein  Carbohydrate  Sugars  \
# 8                                0.143    95.0     0.14         21.92   13.88
# 12                               0.211    84.0     6.72          1.26    0.51
# 27                               0.000    63.0     0.00         16.12   16.38
# 28                               0.161   222.0     1.33         39.66   34.11
# 29                               3.509   110.0     1.15         10.54    0.63
#
#     Dietary Fiber  Total Fat  food type
# 8             0.0       0.74        0.0
# 12            0.0       5.78        0.0
# 27            0.0       0.00        0.0
# 28            0.8       6.50        0.0
# 29            0.3       7.09        0.0

# %% [markdown]
# Classify food type:
#
# Code or Value	Value Description
# 0
# 1	Beverage w/ additions
# 2	Cereal w/ additions
# 3	Bread/baked products w/ additions
# 4	Salad
# 5	Sandwiches
# 6	Soup
# 7
# 8	Ice cream/frozen yogurt w/ addition
# 9	Dried beans and vegetable w/ additions
# 10	Fruit w/ additions
# 11	Tortilla products
# 12	Meat, poultry, fish
# 13
# 14	Chips w/ additions
# 90

# %%
dietary = dietary[dietary['food type'] != 0.0]
dietary = dietary[dietary['food type'] != 7.0]
dietary = dietary[dietary['food type'] != 13.0]
dietary = dietary[dietary['food type'] != 90.0]
dietary['food type'].value_counts()
# Out:
# food type
# 1.0     932
# 3.0     602
# 5.0     560
# 2.0     301
# 14.0    216
# 8.0     212
# 10.0    195
# 9.0     178
# 4.0     175
# 11.0    112
# 12.0    102
# 6.0      45
# Name: count, dtype: int64

# %%
# food type 1: Don't need to heat or cook
dietary['food type'] = dietary['food type'].replace(1.0, 'w/o heat or cook')
dietary['food type'] = dietary['food type'].replace(4.0, 'w/o heat or cook')
dietary['food type'] = dietary['food type'].replace(5.0, 'w/o heat or cook')
dietary['food type'] = dietary['food type'].replace(8.0, 'w/o heat or cook')
dietary['food type'] = dietary['food type'].replace(10.0, 'w/o heat or cook')
dietary['food type'] = dietary['food type'].replace(11.0, 'w/o heat or cook')

dietary['food type'] = dietary['food type'].replace(2.0, 'heat or cook')
dietary['food type'] = dietary['food type'].replace(6.0, 'heat or cook')
dietary['food type'] = dietary['food type'].replace(12.0, 'heat or cook')

dietary['food type'] = dietary['food type'].replace(3.0, 'baking')

dietary['food type'] = dietary['food type'].replace(9.0, 'fried')
dietary['food type'] = dietary['food type'].replace(14.0, 'baking')

# %%
dietary.to_csv('/Users/an/Documents/Umich/stats 503/Final Project/dietary.csv', index = False)

# %% [markdown]
# ## Data Inspection

# %%
data_inspection = pd.DataFrame({})
data_inspection['dataset'] = names
data_inspection['rows'] = [df.shape[0] for df in datasets]
data_inspection['cols'] = [df.shape[1] for df in datasets]
data_inspection['null_values'] = [df.isnull().sum().sum() for df in datasets]
data_inspection['n_cols_with_null'] = [len([col for col, null in df.isnull().sum().items() if null > 0]) for df in datasets]
data_inspection['cols_with_null'] = [', '.join([col for col, null in df.isnull().sum().items() if null > 0]) for df in datasets]

data_inspection.style.background_gradient()

# %%
dietary.isna().sum()
# Out:
# Total saturated fatty acids           0
# Total monounsaturated fatty acids     0
#  Total polyunsaturated fatty acids    0
# Energy                                0
# Protein                               0
# Carbohydrate                          0
# Sugars                                0
# Dietary Fiber                         0
# Total Fat                             0
# food type                             0
# dtype: int64

# %%
sns.pairplot(dietary)

# %%
dietary['food type'].value_counts()
# Out:
# food type
# w/o heat or cook    2186
# baking               818
# heat or cook         448
# fried                178
# Name: count, dtype: int64

# %%
plt.figure(figsize = (10, 6))
plt.hist(dietary['food type'])
# Out:
# (array([ 818.,    0.,    0., 2186.,    0.,    0.,  448.,    0.,    0.,
#          178.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
dietary.isna().sum()
# Out:
# Total saturated fatty acids           0
# Total monounsaturated fatty acids     0
#  Total polyunsaturated fatty acids    0
# Energy                                0
# Protein                               0
# Carbohydrate                          0
# Sugars                                0
# Dietary Fiber                         0
# Total Fat                             0
# food type                             0
# dtype: int64
